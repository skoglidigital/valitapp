# %%
import ifcopenshell
import ifctester
from ifctester import reporter
from ifctester import ids

# %% [markdown]
# # Create the IDS Renhold (IDS Cleaning)
#
# [IDS docutmentation](https://github.com/buildingSMART/IDS/blob/master/Documentation) in buildingSMART github repo.
#
#
# ## Create IDS
# Start by folling the [metadata guidelines found here.](https://github.com/buildingSMART/IDS/blob/master/Documentation/ids-metadata.md)

# %%
# create new IDS 
# ref https://github.com/buildingSMART/IDS/blob/master/Documentation/ids-metadata.md 
my_ids = ids.Ids(
   title="IDS Renhold",
   author="sigve@mok-see.com",
   copyright="[mok-see] AS",
   version="0.5",
   purpose= "Basis for kalkulere renholdskostnader",
   description="Arkitektmodell kan bli brukt til å kalkulere renholdskostnader hvis den inneholder \
      informasjonen som er definert i denne Informasjons-leveranse-spesifikasjonen (IDS-Informaton Delivery Specification)\
         Denne IDS filen kan brukes for å automatisk validere at en IFC-modell. \
            Prosjektet er en del av pilotprosjekt i regi av DiBK",
   
   milestone="MMI 500 : Som bygget")

# %% [markdown]
# ## Create specifications

# %% [markdown]
# ## Requirement for naming
# Rooms need to be given proper names and numbering that can be found on in the pphysical building

# %%
# Create naming specification
naming_spec = ids.Specification(
    name="Navngivning på rom",
    description= "Alle rom må ha et beskrivende navn og romnummer som kan gjennkjennes på merking i bygget",
    instructions="Alle rom må kunne identifiseres med romnavn og romnummer")
naming_spec.applicability.append(ids.Entity(name="IfcSpace"))

name_attr = ids.Attribute(
    name = "LongName",
    instructions="Alle rom må ha et romnavn",
    minOccurs=1
)
naming_spec.requirements.append(name_attr)

number_attr = ids.Attribute(
    name = "Name",
    instructions="Alle rom må ha et romnummer",
    minOccurs=1
)
naming_spec.requirements.append(number_attr)
# Add specification to ids.
my_ids.specifications.append(naming_spec)

# %%
# Create covering specification
covering_spec = ids.Specification(
    name="Dekkende materialer på rom",
    description= "Alle rom må ha referanse til dekkene som kler rommet",
    instructions="Alle rom må referanse til dekkene som kler rommet, som gir referanse til IfcCovering")
covering_spec.applicability.append(ids.Entity(name="IfcSpace"))

coverings = ids.Attribute(
    name = "HasCoverings",
    instructions="Alle rom må gi liste av relaterte dekkende flater",
    minOccurs=1
)
covering_spec.requirements.append(coverings)
my_ids.specifications.append(covering_spec)

# %% [markdown]
# ## Requirement for room size
# The size of the room is required in order to estimate cleaning costs

# %%
room_size_spec = ids.Specification(
    name="Størrelser på rom",
    description= "Romstørrelser må oppgis for å kunne kalkulere renholdskostnader",
    instructions="Alle rom må oppgi nødvendige størrelser for å kunne kalkulere riktige renholdskostnader per rom",
    ifcVersion = "IFC4")
room_size_spec.applicability.append(ids.Entity(name="IfcSpace"))

netFloorArea = ids.Property(
    name="NetFloorArea", 
    propertySet="Qto_SpaceBaseQuantities", 
    measure="IfcAreaMeasure",
    instructions="Netto gulvareal må være oppgitt per rom",
    minOccurs=1
    )
room_size_spec.requirements.append(netFloorArea)

finishCeilingHeight = ids.Property(
    name="FinishCeilingHeight", 
    propertySet="Qto_SpaceBaseQuantities", 
    measure="IfcLengthMeasure",
    instructions="Himlingshøyde, netto høyde på rommet, må være oppgitt for hver rom",
    minOccurs=1
    )
room_size_spec.requirements.append(finishCeilingHeight)

concealedCeiling = ids.Property(
    name="ConcealedCeiling", 
    propertySet="Pset_SpaceCoveringRequirements", 
    measure="IfcBoolean",
    instructions="Det må være oppgitt om det er åpen eller lukket himling på rommet",
    minOccurs=1
    )
room_size_spec.requirements.append(concealedCeiling)


my_ids.specifications.append(room_size_spec)

# %% [markdown]
# ## Requirements for walls and floors and the realtion to rooms
# Walls under 3 meter need to be cleaned, hence their net area and finish needs to be provided

# %%
## Coverings

room_covering_spec = ids.Specification(
    name="Overflater i rommet",
    description= "Overflater må oppgis for å kunne kalkulere renholdskostnader",
    instructions="Alle rom må oppgi nødvendige overflatematerialer for å kunne kalkulere riktige renholdskostnader per rom",
    ifcVersion = "IFC4")
room_covering_spec.applicability.append(ids.Entity(name="IfcSpace"))

wallCovering = ids.Property(
    name="WallCovering", 
    measure="IfcLabel",
    propertySet="Pset_SpaceCoveringRequirements", 
    instructions="Overflater på vegger må være angitt",
    minOccurs=1
    )
room_covering_spec.requirements.append(wallCovering)

floorCovering = ids.Property(
    name="FloorCovering", 
    propertySet="Pset_SpaceCoveringRequirements",
    measure="IfcLabel",
    instructions="Overflater på gulv må være angitt",
    minOccurs=1
    )
room_covering_spec.requirements.append(floorCovering)

ceilingCovering = ids.Property(
    name="CeilingCovering", 
    measure="IfcLabel",
    propertySet="Pset_SpaceCoveringRequirements", 
    instructions="Overflater på vegger må være angitt",
    minOccurs=1
    )
room_covering_spec.requirements.append(ceilingCovering)
my_ids.specifications.append(room_covering_spec)

# %%
# Vegger på opp til 3 meter skal oppgis nettoareal på
wall_spec = ids.Specification(
    name="Veggareal for vegger under 3 meter",
    description= "Alle vegger opp til og med 3 meter skal vaskes iht. INSTA800",
    instructions="Alle vegger opp til og med 3 meter må ha oppgitt nettoareal for å kunne kalkulere renholdskostnader",
    ifcVersion = "IFC4",
    minOccurs = 1
)
wall_spec.applicability.append(ids.Entity(name="IfcWall"))
#wall_spec.applicability.append(ids.Entity("IfcWallStandardCase"))
wall_value_restriction = ids.Restriction(options={ "maxInclusive": 3})
wall_spec.applicability.append(ids.Property(
    propertySet="Qto_WallBaseQuantities",
    name="Height",
    measure="IfcLengthMeasure",
    value=wall_value_restriction
    )
)

netWallArea = ids.Property(
    name="NetSideArea", 
    propertySet="Qto_WallBaseQuantities", 
    measure="IfcAreaMeasure",
    instructions="Alle vegger på 3 m eller mindre må ha oppgitt netto areal",
    minOccurs=1
    )
wall_spec.requirements.append(netWallArea)

wall_material = ids.Material(minOccurs=1 ,instructions="Walls must have materials")
wall_spec.requirements.append(wall_material)

my_ids.specifications.append(wall_spec)

my_ids.specifications.append(wall_spec)

# %%
# lager fil
my_ids.to_xml("renholds.ids")
# Out:
# True

# %%
# open  IFC file:
from ifctester import ids , reporter
import ifcopenshell

my_ifc = ifcopenshell.open("1170101-00-000-A-20_1st.ifc")
testids = ids.open("complex_test.ids")
# validate IFC model against IDS requirements:
testids.validate(my_ifc)
# show results:
reporter.Json(testids).report()
# Out:
# 0 <ifctester.facet.Entity object at 0x7f39eb3aefe0>
# entered entity filter
# 1 <ifctester.facet.Property object at 0x7f39eb3aece0>
# Property Facet call function triggered
# #119694=IfcQuantityLength('Height',$,$,3079.99999999991,$)
# #119695=IfcQuantityLength('Length',$,$,5359.91037819686,$)
# #119696=IfcQuantityLength('Width',$,$,270.,$)
# #119697=IfcQuantityArea('GrossFootprintArea',$,$,1.44093897219979,$)
# #119698=IfcQuantityVolume('NetVolume',$,$,4457301470.50837,$)
# #119699=IfcQuantityArea('NetSideArea',$,$,16508523.9648458,$)
# #119700=IfcQuantityArea('NetSideArea',$,$,10.3605239648458,$)
# #119701=IfcQuantityVolume('NetVolume',$,$,2.77813203437522,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.07999999999991
# whateverland?
# Property Facet call function triggered
# #120114=IfcQuantityLength('Height',$,$,3250.00000000018,$)
# #120115=IfcQuantityLength('Length',$,$,27018.3017900682,$)
# #120116=IfcQuantityLength('Width',$,$,200.,$)
# #120117=IfcQuantityArea('GrossFootprintArea',$,$,5.40366035801361,$)
# #120118=IfcQuantityVolume('NetVolume',$,$,17561896163.5453,$)
# #120119=IfcQuantityArea('NetSideArea',$,$,87809480.8177266,$)
# #120120=IfcQuantityArea('NetSideArea',$,$,62.0491858177345,$)
# #120121=IfcQuantityVolume('NetVolume',$,$,12.4098371635469,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.2500000000001803
# whateverland?
# Property Facet call function triggered
# #120570=IfcQuantityLength('Height',$,$,3820.,$)
# #120571=IfcQuantityLength('Length',$,$,21787.9159441074,$)
# #120572=IfcQuantityLength('Width',$,$,300.,$)
# #120573=IfcQuantityVolume('NetVolume',$,$,24968951671.9471,$)
# #120574=IfcQuantityArea('NetSideArea',$,$,83229838.9064903,$)
# #120575=IfcQuantityArea('NetSideArea',$,$,59.5085889064902,$)
# #120576=IfcQuantityVolume('NetVolume',$,$,17.0679462791145,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.8200000000000003
# whateverland?
# Property Facet call function triggered
# #121412=IfcQuantityLength('Height',$,$,16068.2033656988,$)
# #121413=IfcQuantityLength('Length',$,$,18780.0397315381,$)
# #121414=IfcQuantityLength('Width',$,$,300.,$)
# #121415=IfcQuantityArea('GrossFootprintArea',$,$,5.63327951979167,$)
# #121416=IfcQuantityVolume('NetVolume',$,$,90528449286.6775,$)
# #121417=IfcQuantityArea('NetSideArea',$,$,301761497.622258,$)
# #121418=IfcQuantityArea('NetSideArea',$,$,224.180567504434,$)
# #121419=IfcQuantityVolume('NetVolume',$,$,67.2424019044914,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 16.0682033656988
# whateverland?
# Property Facet call function triggered
# #121987=IfcQuantityLength('Height',$,$,3805.00000000027,$)
# #121988=IfcQuantityLength('Length',$,$,18779.3534012601,$)
# #121989=IfcQuantityLength('Width',$,$,300.,$)
# #121990=IfcQuantityArea('GrossFootprintArea',$,$,5.63307362070826,$)
# #121991=IfcQuantityVolume('NetVolume',$,$,21436631907.5399,$)
# #121992=IfcQuantityArea('NetSideArea',$,$,71455439.6917997,$)
# #121993=IfcQuantityArea('NetSideArea',$,$,56.1186903189006,$)
# #121994=IfcQuantityVolume('NetVolume',$,$,16.8328203149267,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.80500000000027
# whateverland?
# Property Facet call function triggered
# #122221=IfcQuantityLength('Height',$,$,3820.,$)
# #122222=IfcQuantityLength('Length',$,$,8882.94172282462,$)
# #122223=IfcQuantityLength('Width',$,$,300.,$)
# #122224=IfcQuantityArea('GrossFootprintArea',$,$,2.66488251684739,$)
# #122225=IfcQuantityVolume('NetVolume',$,$,10179851214.357,$)
# #122226=IfcQuantityArea('NetSideArea',$,$,33932837.38119,$)
# #122227=IfcQuantityArea('NetSideArea',$,$,22.1643997141348,$)
# #122228=IfcQuantityVolume('NetVolume',$,$,6.64931991424035,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.8200000000000003
# whateverland?
# Property Facet call function triggered
# #122541=IfcQuantityLength('Height',$,$,3820.,$)
# #122542=IfcQuantityLength('Length',$,$,24615.0681089166,$)
# #122543=IfcQuantityLength('Width',$,$,300.,$)
# #122544=IfcQuantityArea('GrossFootprintArea',$,$,7.37883015238856,$)
# #122545=IfcQuantityVolume('NetVolume',$,$,28208868052.8184,$)
# #122546=IfcQuantityArea('NetSideArea',$,$,94029560.1760613,$)
# #122547=IfcQuantityArea('NetSideArea',$,$,65.4983169606758,$)
# #122548=IfcQuantityVolume('NetVolume',$,$,19.6277582175085,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.8200000000000003
# whateverland?
# Property Facet call function triggered
# #123880=IfcQuantityLength('Height',$,$,16068.2033656988,$)
# #123881=IfcQuantityLength('Length',$,$,24334.6305991358,$)
# #123882=IfcQuantityLength('Width',$,$,300.,$)
# #123883=IfcQuantityArea('GrossFootprintArea',$,$,7.29117792106429,$)
# #123884=IfcQuantityVolume('NetVolume',$,$,117304137988.821,$)
# #123885=IfcQuantityArea('NetSideArea',$,$,391013793.29607,$)
# #123886=IfcQuantityArea('NetSideArea',$,$,280.752837650478,$)
# #123887=IfcQuantityVolume('NetVolume',$,$,84.101379611154,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 16.0682033656988
# whateverland?
# Property Facet call function triggered
# #124310=IfcQuantityLength('Height',$,$,3819.99999999991,$)
# #124311=IfcQuantityLength('Length',$,$,24334.6257274201,$)
# #124312=IfcQuantityLength('Width',$,$,300.,$)
# #124313=IfcQuantityArea('GrossFootprintArea',$,$,7.29117645954958,$)
# #124314=IfcQuantityVolume('NetVolume',$,$,27887481083.6227,$)
# #124315=IfcQuantityArea('NetSideArea',$,$,92958270.2787425,$)
# #124316=IfcQuantityArea('NetSideArea',$,$,70.9031185004855,$)
# #124317=IfcQuantityVolume('NetVolume',$,$,21.2413440754787,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.81999999999991
# whateverland?
# Property Facet call function triggered
# #124766=IfcQuantityLength('Height',$,$,3819.99999999991,$)
# #124767=IfcQuantityLength('Length',$,$,50119.2617436063,$)
# #124768=IfcQuantityLength('Width',$,$,300.,$)
# #124769=IfcQuantityArea('GrossFootprintArea',$,$,15.025347166704,$)
# #124770=IfcQuantityVolume('NetVolume',$,$,57436673958.1715,$)
# #124771=IfcQuantityArea('NetSideArea',$,$,191455579.860572,$)
# #124772=IfcQuantityArea('NetSideArea',$,$,139.71135626085,$)
# #124773=IfcQuantityVolume('NetVolume',$,$,41.8884761768074,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.81999999999991
# whateverland?
# Property Facet call function triggered
# #124900=IfcQuantityLength('Height',$,$,3820.,$)
# #124901=IfcQuantityLength('Length',$,$,1691.32688394633,$)
# #124902=IfcQuantityLength('Width',$,$,300.,$)
# #124903=IfcQuantityArea('GrossFootprintArea',$,$,0.505430874039836,$)
# #124904=IfcQuantityVolume('NetVolume',$,$,1938260609.00249,$)
# #124905=IfcQuantityArea('NetSideArea',$,$,6460868.69667497,$)
# #124906=IfcQuantityArea('NetSideArea',$,$,6.46086869667497,$)
# #124907=IfcQuantityVolume('NetVolume',$,$,1.93074593883217,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.8200000000000003
# whateverland?
# Property Facet call function triggered
# #126155=IfcQuantityLength('Height',$,$,16808.2033656988,$)
# #126156=IfcQuantityLength('Length',$,$,23707.4643085914,$)
# #126157=IfcQuantityLength('Width',$,$,300.,$)
# #126158=IfcQuantityArea('GrossFootprintArea',$,$,7.10651166295127,$)
# #126159=IfcQuantityVolume('NetVolume',$,$,119543964415.155,$)
# #126160=IfcQuantityArea('NetSideArea',$,$,398479881.383851,$)
# #126161=IfcQuantityArea('NetSideArea',$,$,261.541285612712,$)
# #126162=IfcQuantityVolume('NetVolume',$,$,78.3661145202543,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 16.808203365698798
# whateverland?
# Property Facet call function triggered
# #126677=IfcQuantityLength('Height',$,$,3129.99999999991,$)
# #126678=IfcQuantityLength('Length',$,$,26816.8214568781,$)
# #126679=IfcQuantityLength('Width',$,$,200.,$)
# #126680=IfcQuantityArea('GrossFootprintArea',$,$,5.36334214465416,$)
# #126681=IfcQuantityVolume('NetVolume',$,$,16787330232.0052,$)
# #126682=IfcQuantityArea('NetSideArea',$,$,83936651.1600262,$)
# #126683=IfcQuantityArea('NetSideArea',$,$,58.3267993591496,$)
# #126684=IfcQuantityVolume('NetVolume',$,$,11.6652905525918,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.12999999999991
# whateverland?
# Property Facet call function triggered
# #127595=IfcQuantityLength('Height',$,$,3800.,$)
# #127596=IfcQuantityLength('Length',$,$,1728.17454062784,$)
# #127597=IfcQuantityLength('Width',$,$,300.,$)
# #127598=IfcQuantityArea('GrossFootprintArea',$,$,0.518452362188353,$)
# #127599=IfcQuantityVolume('NetVolume',$,$,1970118976.31574,$)
# #127600=IfcQuantityArea('NetSideArea',$,$,6567063.25438579,$)
# #127601=IfcQuantityArea('NetSideArea',$,$,6.56706325438578,$)
# #127602=IfcQuantityVolume('NetVolume',$,$,1.97011897631574,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.8000000000000003
# whateverland?
# Property Facet call function triggered
# #129636=IfcQuantityLength('Height',$,$,19888.2033656985,$)
# #129637=IfcQuantityLength('Length',$,$,9402.66575780565,$)
# #129638=IfcQuantityLength('Width',$,$,300.,$)
# #129639=IfcQuantityVolume('NetVolume',$,$,56100638631.2786,$)
# #129640=IfcQuantityArea('NetSideArea',$,$,187002128.770929,$)
# #129641=IfcQuantityArea('NetSideArea',$,$,187.002128770929,$)
# #129642=IfcQuantityVolume('NetVolume',$,$,55.95762960485,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 19.8882033656985
# whateverland?
# Property Facet call function triggered
# #130648=IfcQuantityLength('Height',$,$,16808.2033656988,$)
# #130649=IfcQuantityLength('Length',$,$,35776.8690673683,$)
# #130650=IfcQuantityLength('Width',$,$,300.,$)
# #130651=IfcQuantityVolume('NetVolume',$,$,180403467321.692,$)
# #130652=IfcQuantityArea('NetSideArea',$,$,601344891.072307,$)
# #130653=IfcQuantityArea('NetSideArea',$,$,394.768891574555,$)
# #130654=IfcQuantityVolume('NetVolume',$,$,118.334396308808,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 16.808203365698798
# whateverland?
# Property Facet call function triggered
# #131224=IfcQuantityLength('Height',$,$,2289.9999999999,$)
# #131225=IfcQuantityLength('Length',$,$,20268.3053850364,$)
# #131226=IfcQuantityLength('Width',$,$,250.,$)
# #131227=IfcQuantityArea('GrossFootprintArea',$,$,4.53488993167276,$)
# #131228=IfcQuantityVolume('NetVolume',$,$,11603604832.9328,$)
# #131229=IfcQuantityArea('NetSideArea',$,$,46414419.3317313,$)
# #131230=IfcQuantityArea('NetSideArea',$,$,34.4024193317314,$)
# #131231=IfcQuantityVolume('NetVolume',$,$,7.69729792841152,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.2899999999999
# Property Facet call function triggered
# #132560=IfcQuantityLength('Height',$,$,16068.2033656988,$)
# #132561=IfcQuantityLength('Length',$,$,50119.2329453208,$)
# #132562=IfcQuantityLength('Width',$,$,300.,$)
# #132563=IfcQuantityArea('GrossFootprintArea',$,$,15.0253385272184,$)
# #132564=IfcQuantityVolume('NetVolume',$,$,241597808249.473,$)
# #132565=IfcQuantityArea('NetSideArea',$,$,805326027.498245,$)
# #132566=IfcQuantityArea('NetSideArea',$,$,546.644373332693,$)
# #132567=IfcQuantityVolume('NetVolume',$,$,163.888445093812,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 16.0682033656988
# whateverland?
# Property Facet call function triggered
# #132670=IfcQuantityLength('Height',$,$,2909.99999999999,$)
# #132671=IfcQuantityLength('Length',$,$,3576.25689675893,$)
# #132672=IfcQuantityLength('Width',$,$,100.,$)
# #132673=IfcQuantityArea('GrossFootprintArea',$,$,0.357625689675905,$)
# #132674=IfcQuantityVolume('NetVolume',$,$,1040690756.95685,$)
# #132675=IfcQuantityArea('NetSideArea',$,$,10406907.5695685,$)
# #132676=IfcQuantityArea('NetSideArea',$,$,10.4069075695685,$)
# #132677=IfcQuantityVolume('NetVolume',$,$,1.04069075695684,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.90999999999999
# Property Facet call function triggered
# #132943=IfcQuantityLength('Height',$,$,2909.99999999999,$)
# #132944=IfcQuantityLength('Length',$,$,3609.99999999999,$)
# #132945=IfcQuantityLength('Width',$,$,100.,$)
# #132946=IfcQuantityArea('GrossFootprintArea',$,$,0.360999999999995,$)
# #132947=IfcQuantityVolume('NetVolume',$,$,1050509999.99999,$)
# #132948=IfcQuantityArea('NetSideArea',$,$,10505099.9999999,$)
# #132949=IfcQuantityArea('NetSideArea',$,$,9.64599999999994,$)
# #132950=IfcQuantityVolume('NetVolume',$,$,0.964599999999994,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.90999999999999
# Property Facet call function triggered
# #133123=IfcQuantityLength('Height',$,$,2880.,$)
# #133124=IfcQuantityLength('Length',$,$,3609.9999998874,$)
# #133125=IfcQuantityLength('Width',$,$,100.,$)
# #133126=IfcQuantityArea('GrossFootprintArea',$,$,0.360999999988736,$)
# #133127=IfcQuantityVolume('NetVolume',$,$,1039679999.96757,$)
# #133128=IfcQuantityArea('NetSideArea',$,$,10396799.9996757,$)
# #133129=IfcQuantityArea('NetSideArea',$,$,9.53769999967571,$)
# #133130=IfcQuantityVolume('NetVolume',$,$,0.953769999967571,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.88
# Property Facet call function triggered
# #133239=IfcQuantityLength('Height',$,$,2880.,$)
# #133240=IfcQuantityLength('Length',$,$,670.999937575351,$)
# #133241=IfcQuantityLength('Width',$,$,96.,$)
# #133242=IfcQuantityArea('GrossFootprintArea',$,$,0.0644159940072336,$)
# #133243=IfcQuantityVolume('NetVolume',$,$,185518062.740833,$)
# #133244=IfcQuantityArea('NetSideArea',$,$,1932479.82021701,$)
# #133245=IfcQuantityArea('NetSideArea',$,$,1.93247982021701,$)
# #133246=IfcQuantityVolume('NetVolume',$,$,0.185518062740833,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.88
# Property Facet call function triggered
# #133437=IfcQuantityLength('Height',$,$,2759.9999999999,$)
# #133438=IfcQuantityLength('Length',$,$,2393.31519402628,$)
# #133439=IfcQuantityLength('Width',$,$,122.,$)
# #133440=IfcQuantityArea('GrossFootprintArea',$,$,0.291984453671202,$)
# #133441=IfcQuantityVolume('NetVolume',$,$,805877092.132501,$)
# #133442=IfcQuantityArea('NetSideArea',$,$,6605549.9355123,$)
# #133443=IfcQuantityArea('NetSideArea',$,$,6.6055499355123,$)
# #133444=IfcQuantityVolume('NetVolume',$,$,0.805877092132504,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.7599999999999
# Property Facet call function triggered
# #133693=IfcQuantityLength('Height',$,$,2849.99999999991,$)
# #133694=IfcQuantityLength('Length',$,$,2037.,$)
# #133695=IfcQuantityLength('Width',$,$,122.,$)
# #133696=IfcQuantityArea('GrossFootprintArea',$,$,0.248514000000001,$)
# #133697=IfcQuantityVolume('NetVolume',$,$,708264899.999976,$)
# #133698=IfcQuantityArea('NetSideArea',$,$,5805449.9999998,$)
# #133699=IfcQuantityArea('NetSideArea',$,$,3.67434999999984,$)
# #133700=IfcQuantityVolume('NetVolume',$,$,0.448270699999981,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.84999999999991
# Property Facet call function triggered
# #133809=IfcQuantityLength('Height',$,$,2880.,$)
# #133810=IfcQuantityLength('Length',$,$,2004.31559358195,$)
# #133811=IfcQuantityLength('Width',$,$,100.,$)
# #133812=IfcQuantityArea('GrossFootprintArea',$,$,0.200431559358193,$)
# #133813=IfcQuantityVolume('NetVolume',$,$,577242890.951604,$)
# #133814=IfcQuantityArea('NetSideArea',$,$,5772428.90951604,$)
# #133815=IfcQuantityArea('NetSideArea',$,$,5.77242890951603,$)
# #133816=IfcQuantityVolume('NetVolume',$,$,0.577242890951603,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.88
# Property Facet call function triggered
# #133983=IfcQuantityLength('Height',$,$,2899.99999999991,$)
# #133984=IfcQuantityLength('Length',$,$,2289.35276630148,$)
# #133985=IfcQuantityLength('Width',$,$,122.,$)
# #133986=IfcQuantityArea('GrossFootprintArea',$,$,0.279301037488776,$)
# #133987=IfcQuantityVolume('NetVolume',$,$,809973008.717438,$)
# #133988=IfcQuantityArea('NetSideArea',$,$,6639123.02227408,$)
# #133989=IfcQuantityArea('NetSideArea',$,$,4.50802302227412,$)
# #133990=IfcQuantityVolume('NetVolume',$,$,0.549978808717444,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.89999999999991
# Property Facet call function triggered
# #137137=IfcQuantityLength('Height',$,$,2880.,$)
# #137138=IfcQuantityLength('Length',$,$,4649.99999999998,$)
# #137139=IfcQuantityLength('Width',$,$,100.,$)
# #137140=IfcQuantityArea('GrossFootprintArea',$,$,0.465000000000004,$)
# #137141=IfcQuantityVolume('NetVolume',$,$,1339200000.,$)
# #137142=IfcQuantityArea('NetSideArea',$,$,13392000.,$)
# #137143=IfcQuantityArea('NetSideArea',$,$,12.5329,$)
# #137144=IfcQuantityVolume('NetVolume',$,$,1.25329,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.88
# Property Facet call function triggered
# #137322=IfcQuantityLength('Height',$,$,2299.9999999999,$)
# #137323=IfcQuantityLength('Length',$,$,2431.48871942545,$)
# #137324=IfcQuantityLength('Width',$,$,96.,$)
# #137325=IfcQuantityArea('GrossFootprintArea',$,$,0.233422917064853,$)
# #137326=IfcQuantityVolume('NetVolume',$,$,536872709.249116,$)
# #137327=IfcQuantityArea('NetSideArea',$,$,5592424.05467829,$)
# #137328=IfcQuantityArea('NetSideArea',$,$,5.59242405467829,$)
# #137329=IfcQuantityVolume('NetVolume',$,$,0.536872709249116,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.2999999999999
# Property Facet call function triggered
# #137599=IfcQuantityLength('Height',$,$,2299.9999999999,$)
# #137600=IfcQuantityLength('Length',$,$,2825.5367623808,$)
# #137601=IfcQuantityLength('Width',$,$,122.,$)
# #137602=IfcQuantityArea('GrossFootprintArea',$,$,0.344715485010459,$)
# #137603=IfcQuantityVolume('NetVolume',$,$,792845615.524018,$)
# #137604=IfcQuantityArea('NetSideArea',$,$,6498734.55347556,$)
# #137605=IfcQuantityArea('NetSideArea',$,$,6.49873455347556,$)
# #137606=IfcQuantityVolume('NetVolume',$,$,0.792845615524021,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.2999999999999
# Property Facet call function triggered
# #140733=IfcQuantityLength('Height',$,$,2962.18399246247,$)
# #140734=IfcQuantityLength('Length',$,$,2006.,$)
# #140735=IfcQuantityLength('Width',$,$,122.,$)
# #140736=IfcQuantityArea('GrossFootprintArea',$,$,0.244732000000001,$)
# #140737=IfcQuantityVolume('NetVolume',$,$,724941212.843325,$)
# #140738=IfcQuantityArea('NetSideArea',$,$,5942141.08887971,$)
# #140739=IfcQuantityArea('NetSideArea',$,$,3.17804108887975,$)
# #140740=IfcQuantityVolume('NetVolume',$,$,0.387721012843331,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.96218399246247
# Property Facet call function triggered
# #140909=IfcQuantityLength('Height',$,$,2264.36530108905,$)
# #140910=IfcQuantityLength('Length',$,$,2205.31559358249,$)
# #140911=IfcQuantityLength('Width',$,$,100.,$)
# #140912=IfcQuantityArea('GrossFootprintArea',$,$,0.220531559358251,$)
# #140913=IfcQuantityVolume('NetVolume',$,$,499364010.80588,$)
# #140914=IfcQuantityArea('NetSideArea',$,$,4993640.1080588,$)
# #140915=IfcQuantityArea('NetSideArea',$,$,4.13454010805882,$)
# #140916=IfcQuantityVolume('NetVolume',$,$,0.413454010805882,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.26436530108905
# Property Facet call function triggered
# #141081=IfcQuantityLength('Height',$,$,3000.00000000004,$)
# #141082=IfcQuantityLength('Length',$,$,2236.65436133721,$)
# #141083=IfcQuantityLength('Width',$,$,122.,$)
# #141084=IfcQuantityArea('GrossFootprintArea',$,$,0.272871832083136,$)
# #141085=IfcQuantityVolume('NetVolume',$,$,818615496.249431,$)
# #141086=IfcQuantityArea('NetSideArea',$,$,6709963.08401173,$)
# #141087=IfcQuantityArea('NetSideArea',$,$,4.57886308401177,$)
# #141088=IfcQuantityVolume('NetVolume',$,$,0.558621296249438,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.00000000000004
# whateverland?
# Property Facet call function triggered
# #141414=IfcQuantityLength('Height',$,$,2299.9999999999,$)
# #141415=IfcQuantityLength('Length',$,$,4550.00003623965,$)
# #141416=IfcQuantityLength('Width',$,$,100.,$)
# #141417=IfcQuantityArea('GrossFootprintArea',$,$,0.45500000362397,$)
# #141418=IfcQuantityVolume('NetVolume',$,$,1046500008.33507,$)
# #141419=IfcQuantityArea('NetSideArea',$,$,10465000.0833507,$)
# #141420=IfcQuantityArea('NetSideArea',$,$,9.60590008335075,$)
# #141421=IfcQuantityVolume('NetVolume',$,$,0.960590008335075,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.2999999999999
# Property Facet call function triggered
# #141530=IfcQuantityLength('Height',$,$,2300.,$)
# #141531=IfcQuantityLength('Length',$,$,427.500217183613,$)
# #141532=IfcQuantityLength('Width',$,$,122.,$)
# #141533=IfcQuantityArea('GrossFootprintArea',$,$,0.0521550264964001,$)
# #141534=IfcQuantityVolume('NetVolume',$,$,119956560.941722,$)
# #141535=IfcQuantityArea('NetSideArea',$,$,983250.499522309,$)
# #141536=IfcQuantityArea('NetSideArea',$,$,0.983250499522311,$)
# #141537=IfcQuantityVolume('NetVolume',$,$,0.119956560941722,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.3000000000000003
# Property Facet call function triggered
# #141655=IfcQuantityLength('Height',$,$,1915.17909404166,$)
# #141656=IfcQuantityLength('Length',$,$,30870.0529705597,$)
# #141657=IfcQuantityLength('Width',$,$,150.,$)
# #141658=IfcQuantityArea('GrossFootprintArea',$,$,4.62858293659129,$)
# #141659=IfcQuantityVolume('NetVolume',$,$,8868252012.17618,$)
# #141660=IfcQuantityArea('NetSideArea',$,$,59121680.0811745,$)
# #141661=IfcQuantityArea('NetSideArea',$,$,59.1216800811745,$)
# #141662=IfcQuantityVolume('NetVolume',$,$,8.86456527519756,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 1.91517909404166
# Property Facet call function triggered
# #141891=IfcQuantityLength('Height',$,$,2016.24750758688,$)
# #141892=IfcQuantityLength('Length',$,$,4050.00000000007,$)
# #141893=IfcQuantityLength('Width',$,$,150.,$)
# #141894=IfcQuantityVolume('NetVolume',$,$,1224870360.85905,$)
# #141895=IfcQuantityArea('NetSideArea',$,$,8165802.405727,$)
# #141896=IfcQuantityArea('NetSideArea',$,$,5.98384867483594,$)
# #141897=IfcQuantityVolume('NetVolume',$,$,0.897577301225183,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.01624750758688
# Property Facet call function triggered
# #142068=IfcQuantityLength('Height',$,$,2880.,$)
# #142069=IfcQuantityLength('Length',$,$,746.00000000001,$)
# #142070=IfcQuantityLength('Width',$,$,109.,$)
# #142071=IfcQuantityArea('GrossFootprintArea',$,$,0.081314000000002,$)
# #142072=IfcQuantityVolume('NetVolume',$,$,234184320.000004,$)
# #142073=IfcQuantityArea('NetSideArea',$,$,2148480.00000003,$)
# #142074=IfcQuantityArea('NetSideArea',$,$,2.14848000000003,$)
# #142075=IfcQuantityVolume('NetVolume',$,$,0.234184320000006,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.88
# Property Facet call function triggered
# #142359=IfcQuantityLength('Height',$,$,2849.99999999991,$)
# #142360=IfcQuantityLength('Length',$,$,3391.,$)
# #142361=IfcQuantityLength('Width',$,$,96.,$)
# #142362=IfcQuantityArea('GrossFootprintArea',$,$,0.325536,$)
# #142363=IfcQuantityVolume('NetVolume',$,$,927777599.999971,$)
# #142364=IfcQuantityArea('NetSideArea',$,$,9664349.99999969,$)
# #142365=IfcQuantityArea('NetSideArea',$,$,3.69304999999968,$)
# #142366=IfcQuantityVolume('NetVolume',$,$,0.35453279999998,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.84999999999991
# Property Facet call function triggered
# #145365=IfcQuantityLength('Height',$,$,3110.00000000004,$)
# #145366=IfcQuantityLength('Length',$,$,427.501399438193,$)
# #145367=IfcQuantityLength('Width',$,$,122.,$)
# #145368=IfcQuantityArea('GrossFootprintArea',$,$,0.0521551707314626,$)
# #145369=IfcQuantityVolume('NetVolume',$,$,162202580.974841,$)
# #145370=IfcQuantityArea('NetSideArea',$,$,1329529.3522528,$)
# #145371=IfcQuantityArea('NetSideArea',$,$,1.3295293522528,$)
# #145372=IfcQuantityVolume('NetVolume',$,$,0.162202580974839,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.1100000000000403
# whateverland?
# Property Facet call function triggered
# #148360=IfcQuantityLength('Height',$,$,1099.99999999999,$)
# #148361=IfcQuantityLength('Length',$,$,3820.04766580784,$)
# #148362=IfcQuantityLength('Width',$,$,150.,$)
# #148363=IfcQuantityArea('GrossFootprintArea',$,$,0.573007149871177,$)
# #148364=IfcQuantityVolume('NetVolume',$,$,630307864.858289,$)
# #148365=IfcQuantityArea('NetSideArea',$,$,4202052.43238859,$)
# #148366=IfcQuantityArea('NetSideArea',$,$,4.20205243238861,$)
# #148367=IfcQuantityVolume('NetVolume',$,$,0.630307864858293,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 1.09999999999999
# Property Facet call function triggered
# #148542=IfcQuantityLength('Height',$,$,2014.6452782499,$)
# #148543=IfcQuantityLength('Length',$,$,7632.19560086795,$)
# #148544=IfcQuantityLength('Width',$,$,150.,$)
# #148545=IfcQuantityVolume('NetVolume',$,$,2306425024.49524,$)
# #148546=IfcQuantityArea('NetSideArea',$,$,15376166.8299683,$)
# #148547=IfcQuantityArea('NetSideArea',$,$,11.4377709022581,$)
# #148548=IfcQuantityVolume('NetVolume',$,$,1.71158130654641,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.0146452782499003
# Property Facet call function triggered
# #148724=IfcQuantityLength('Height',$,$,2875.00000000018,$)
# #148725=IfcQuantityLength('Length',$,$,5567.74604375833,$)
# #148726=IfcQuantityLength('Width',$,$,150.,$)
# #148727=IfcQuantityArea('GrossFootprintArea',$,$,0.815266339388467,$)
# #148728=IfcQuantityVolume('NetVolume',$,$,2401090481.37093,$)
# #148729=IfcQuantityArea('NetSideArea',$,$,16007269.8758062,$)
# #148730=IfcQuantityArea('NetSideArea',$,$,15.836037037163,$)
# #148731=IfcQuantityVolume('NetVolume',$,$,2.36987036247824,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.8750000000001803
# Property Facet call function triggered
# #148841=IfcQuantityLength('Height',$,$,1910.00000000015,$)
# #148842=IfcQuantityLength('Length',$,$,26812.1338359193,$)
# #148843=IfcQuantityLength('Width',$,$,150.,$)
# #148844=IfcQuantityArea('GrossFootprintArea',$,$,4.02181908412171,$)
# #148845=IfcQuantityVolume('NetVolume',$,$,7681676343.99151,$)
# #148846=IfcQuantityArea('NetSideArea',$,$,51211175.6266101,$)
# #148847=IfcQuantityArea('NetSideArea',$,$,51.21117562661,$)
# #148848=IfcQuantityVolume('NetVolume',$,$,7.68167445067301,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 1.91000000000015
# Property Facet call function triggered
# #149055=IfcQuantityLength('Height',$,$,3230.00000000015,$)
# #149056=IfcQuantityLength('Length',$,$,4968.81707079067,$)
# #149057=IfcQuantityLength('Width',$,$,200.,$)
# #149058=IfcQuantityArea('GrossFootprintArea',$,$,0.993763414158134,$)
# #149059=IfcQuantityVolume('NetVolume',$,$,3209855827.73092,$)
# #149060=IfcQuantityArea('NetSideArea',$,$,16049279.1386546,$)
# #149061=IfcQuantityArea('NetSideArea',$,$,14.4021791386546,$)
# #149062=IfcQuantityVolume('NetVolume',$,$,2.88043582773094,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.23000000000015
# whateverland?
# Property Facet call function triggered
# #149229=IfcQuantityLength('Height',$,$,1770.,$)
# #149230=IfcQuantityLength('Length',$,$,4100.01077057474,$)
# #149231=IfcQuantityLength('Width',$,$,150.,$)
# #149232=IfcQuantityArea('GrossFootprintArea',$,$,0.615001615586213,$)
# #149233=IfcQuantityVolume('NetVolume',$,$,1088552859.5876,$)
# #149234=IfcQuantityArea('NetSideArea',$,$,7257019.0639173,$)
# #149235=IfcQuantityArea('NetSideArea',$,$,7.2570190639173,$)
# #149236=IfcQuantityVolume('NetVolume',$,$,1.08848296801192,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 1.77
# Property Facet call function triggered
# #149475=IfcQuantityLength('Height',$,$,2290.00000000003,$)
# #149476=IfcQuantityLength('Length',$,$,5367.90587748143,$)
# #149477=IfcQuantityLength('Width',$,$,270.,$)
# #149478=IfcQuantityArea('GrossFootprintArea',$,$,1.44309755778376,$)
# #149479=IfcQuantityVolume('NetVolume',$,$,3318976204.04682,$)
# #149480=IfcQuantityArea('NetSideArea',$,$,12292504.4594327,$)
# #149481=IfcQuantityArea('NetSideArea',$,$,6.14450445943264,$)
# #149482=IfcQuantityVolume('NetVolume',$,$,1.64473340732485,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.2900000000000302
# Property Facet call function triggered
# #149656=IfcQuantityLength('Height',$,$,1960.00000000014,$)
# #149657=IfcQuantityLength('Length',$,$,1434.99999800002,$)
# #149658=IfcQuantityLength('Width',$,$,200.,$)
# #149659=IfcQuantityArea('GrossFootprintArea',$,$,0.286999999600007,$)
# #149660=IfcQuantityVolume('NetVolume',$,$,562519999.216049,$)
# #149661=IfcQuantityArea('NetSideArea',$,$,2812599.99608024,$)
# #149662=IfcQuantityArea('NetSideArea',$,$,2.81259999608024,$)
# #149663=IfcQuantityVolume('NetVolume',$,$,0.56251999921605,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 1.96000000000014
# Property Facet call function triggered
# #149848=IfcQuantityLength('Height',$,$,2461.59527223607,$)
# #149849=IfcQuantityLength('Length',$,$,3682.72363207676,$)
# #149850=IfcQuantityLength('Width',$,$,200.,$)
# #149851=IfcQuantityVolume('NetVolume',$,$,1813075016.33444,$)
# #149852=IfcQuantityArea('NetSideArea',$,$,9065375.08167219,$)
# #149853=IfcQuantityArea('NetSideArea',$,$,7.53138340831204,$)
# #149854=IfcQuantityVolume('NetVolume',$,$,1.50575403343737,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.4615952722360697
# Property Facet call function triggered
# #150021=IfcQuantityLength('Height',$,$,3680.00000000015,$)
# #150022=IfcQuantityLength('Length',$,$,3385.97539179033,$)
# #150023=IfcQuantityLength('Width',$,$,200.,$)
# #150024=IfcQuantityArea('GrossFootprintArea',$,$,0.677195078358067,$)
# #150025=IfcQuantityVolume('NetVolume',$,$,2492077888.35779,$)
# #150026=IfcQuantityArea('NetSideArea',$,$,12460389.4417889,$)
# #150027=IfcQuantityArea('NetSideArea',$,$,10.4178894417889,$)
# #150028=IfcQuantityVolume('NetVolume',$,$,2.08357788835779,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.6800000000001503
# whateverland?
# Property Facet call function triggered
# #150219=IfcQuantityLength('Height',$,$,3680.00000000015,$)
# #150220=IfcQuantityLength('Length',$,$,1270.,$)
# #150221=IfcQuantityLength('Width',$,$,200.,$)
# #150222=IfcQuantityArea('GrossFootprintArea',$,$,0.254,$)
# #150223=IfcQuantityVolume('NetVolume',$,$,934720000.000039,$)
# #150224=IfcQuantityArea('NetSideArea',$,$,4673600.00000019,$)
# #150225=IfcQuantityArea('NetSideArea',$,$,2.54250000000021,$)
# #150226=IfcQuantityVolume('NetVolume',$,$,0.508500000000041,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.6800000000001503
# whateverland?
# Property Facet call function triggered
# #153448=IfcQuantityLength('Height',$,$,3180.00000000014,$)
# #153449=IfcQuantityLength('Length',$,$,4256.18141509062,$)
# #153450=IfcQuantityLength('Width',$,$,140.,$)
# #153451=IfcQuantityArea('GrossFootprintArea',$,$,0.595268505912685,$)
# #153452=IfcQuantityVolume('NetVolume',$,$,1894851965.99843,$)
# #153453=IfcQuantityArea('NetSideArea',$,$,13534656.8999888,$)
# #153454=IfcQuantityArea('NetSideArea',$,$,13.5210989200173,$)
# #153455=IfcQuantityVolume('NetVolume',$,$,1.89295384880242,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.18000000000014
# whateverland?
# Property Facet call function triggered
# #153681=IfcQuantityLength('Height',$,$,4000.00000000015,$)
# #153682=IfcQuantityLength('Length',$,$,4919.02182033611,$)
# #153683=IfcQuantityLength('Width',$,$,150.,$)
# #153684=IfcQuantityArea('GrossFootprintArea',$,$,0.737510669109086,$)
# #153685=IfcQuantityVolume('NetVolume',$,$,2951413092.20177,$)
# #153686=IfcQuantityArea('NetSideArea',$,$,19676087.2813452,$)
# #153687=IfcQuantityArea('NetSideArea',$,$,19.6760872813452,$)
# #153688=IfcQuantityVolume('NetVolume',$,$,2.95004267643645,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 4.00000000000015
# whateverland?
# Property Facet call function triggered
# #153866=IfcQuantityLength('Height',$,$,2060.00000000015,$)
# #153867=IfcQuantityLength('Length',$,$,4929.64340609074,$)
# #153868=IfcQuantityLength('Width',$,$,150.,$)
# #153869=IfcQuantityArea('GrossFootprintArea',$,$,0.739446510913613,$)
# #153870=IfcQuantityVolume('NetVolume',$,$,1523259812.48215,$)
# #153871=IfcQuantityArea('NetSideArea',$,$,10155065.4165476,$)
# #153872=IfcQuantityArea('NetSideArea',$,$,10.1550654165476,$)
# #153873=IfcQuantityVolume('NetVolume',$,$,1.52325028006433,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.06000000000015
# Property Facet call function triggered
# #154369=IfcQuantityLength('Height',$,$,2365.00000000014,$)
# #154370=IfcQuantityLength('Length',$,$,1549.68067381791,$)
# #154371=IfcQuantityLength('Width',$,$,170.,$)
# #154372=IfcQuantityArea('GrossFootprintArea',$,$,0.255585408399447,$)
# #154373=IfcQuantityVolume('NetVolume',$,$,623049114.908526,$)
# #154374=IfcQuantityArea('NetSideArea',$,$,3664994.79357956,$)
# #154375=IfcQuantityArea('NetSideArea',$,$,2.99549657546294,$)
# #154376=IfcQuantityVolume('NetVolume',$,$,0.491323985521492,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.36500000000014
# Property Facet call function triggered
# #154781=IfcQuantityLength('Height',$,$,1971.22915622013,$)
# #154782=IfcQuantityLength('Length',$,$,1166.04247023448,$)
# #154783=IfcQuantityLength('Width',$,$,170.,$)
# #154784=IfcQuantityArea('GrossFootprintArea',$,$,0.198354575747135,$)
# #154785=IfcQuantityVolume('NetVolume',$,$,390751275.501915,$)
# #154786=IfcQuantityArea('NetSideArea',$,$,2298536.91471714,$)
# #154787=IfcQuantityArea('NetSideArea',$,$,0.725022234672196,$)
# #154788=IfcQuantityVolume('NetVolume',$,$,0.123076628940771,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 1.97122915622013
# Property Facet call function triggered
# #154895=IfcQuantityLength('Height',$,$,1980.00000000004,$)
# #154896=IfcQuantityLength('Length',$,$,1107.20539495348,$)
# #154897=IfcQuantityLength('Width',$,$,160.,$)
# #154898=IfcQuantityArea('GrossFootprintArea',$,$,0.176896076270776,$)
# #154899=IfcQuantityVolume('NetVolume',$,$,350762669.121268,$)
# #154900=IfcQuantityArea('NetSideArea',$,$,2192266.68200793,$)
# #154901=IfcQuantityArea('NetSideArea',$,$,2.19166426849233,$)
# #154902=IfcQuantityVolume('NetVolume',$,$,0.350254231016142,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 1.98000000000004
# Property Facet call function triggered
# #155062=IfcQuantityLength('Height',$,$,1910.00000000015,$)
# #155063=IfcQuantityLength('Length',$,$,10163.6414739421,$)
# #155064=IfcQuantityLength('Width',$,$,150.,$)
# #155065=IfcQuantityArea('GrossFootprintArea',$,$,1.52262121209865,$)
# #155066=IfcQuantityVolume('NetVolume',$,$,2911883282.28464,$)
# #155067=IfcQuantityArea('NetSideArea',$,$,19412555.2152309,$)
# #155068=IfcQuantityArea('NetSideArea',$,$,19.4125552152309,$)
# #155069=IfcQuantityVolume('NetVolume',$,$,2.90820651510864,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 1.91000000000015
# Property Facet call function triggered
# #161288=IfcQuantityLength('Height',$,$,2873.91921415891,$)
# #161289=IfcQuantityLength('Length',$,$,3151.43724230439,$)
# #161290=IfcQuantityLength('Width',$,$,122.,$)
# #161291=IfcQuantityArea('GrossFootprintArea',$,$,0.384475343561137,$)
# #161292=IfcQuantityVolume('NetVolume',$,$,1104951077.2307,$)
# #161293=IfcQuantityArea('NetSideArea',$,$,9056976.04287458,$)
# #161294=IfcQuantityArea('NetSideArea',$,$,6.92587604287464,$)
# #161295=IfcQuantityVolume('NetVolume',$,$,0.844956877230708,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.87391921415891
# Property Facet call function triggered
# #164502=IfcQuantityLength('Height',$,$,2880.,$)
# #164503=IfcQuantityLength('Length',$,$,807.459490022689,$)
# #164504=IfcQuantityLength('Width',$,$,96.,$)
# #164505=IfcQuantityArea('GrossFootprintArea',$,$,0.077516111042178,$)
# #164506=IfcQuantityVolume('NetVolume',$,$,223246399.801474,$)
# #164507=IfcQuantityArea('NetSideArea',$,$,2325483.33126535,$)
# #164508=IfcQuantityArea('NetSideArea',$,$,2.32548333126534,$)
# #164509=IfcQuantityVolume('NetVolume',$,$,0.223246399801473,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.88
# Property Facet call function triggered
# #164673=IfcQuantityLength('Height',$,$,3000.00000000004,$)
# #164674=IfcQuantityLength('Length',$,$,2952.83089872371,$)
# #164675=IfcQuantityLength('Width',$,$,122.,$)
# #164676=IfcQuantityArea('GrossFootprintArea',$,$,0.360245369644294,$)
# #164677=IfcQuantityVolume('NetVolume',$,$,1080736108.93289,$)
# #164678=IfcQuantityArea('NetSideArea',$,$,8858492.69617123,$)
# #164679=IfcQuantityArea('NetSideArea',$,$,6.10749269617131,$)
# #164680=IfcQuantityVolume('NetVolume',$,$,0.745114108932902,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.00000000000004
# whateverland?
# Property Facet call function triggered
# #164787=IfcQuantityLength('Height',$,$,2880.,$)
# #164788=IfcQuantityLength('Length',$,$,750.000000000001,$)
# #164789=IfcQuantityLength('Width',$,$,96.,$)
# #164790=IfcQuantityArea('GrossFootprintArea',$,$,0.0719999999999999,$)
# #164791=IfcQuantityVolume('NetVolume',$,$,207360000.000001,$)
# #164792=IfcQuantityArea('NetSideArea',$,$,2160000.00000001,$)
# #164793=IfcQuantityArea('NetSideArea',$,$,2.16,$)
# #164794=IfcQuantityVolume('NetVolume',$,$,0.20736,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.88
# Property Facet call function triggered
# #164901=IfcQuantityLength('Height',$,$,554.999999999995,$)
# #164902=IfcQuantityLength('Length',$,$,3530.05598629311,$)
# #164903=IfcQuantityLength('Width',$,$,5.,$)
# #164904=IfcQuantityArea('GrossFootprintArea',$,$,0.0176502799314655,$)
# #164905=IfcQuantityVolume('NetVolume',$,$,9795905.36196328,$)
# #164906=IfcQuantityArea('NetSideArea',$,$,1959181.07239266,$)
# #164907=IfcQuantityArea('NetSideArea',$,$,1.95918107239266,$)
# #164908=IfcQuantityVolume('NetVolume',$,$,0.00979590536196323,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 0.554999999999995
# Property Facet call function triggered
# #165070=IfcQuantityLength('Height',$,$,554.999999999995,$)
# #165071=IfcQuantityLength('Length',$,$,3547.499788,$)
# #165072=IfcQuantityLength('Width',$,$,5.,$)
# #165073=IfcQuantityArea('GrossFootprintArea',$,$,0.0177374989400001,$)
# #165074=IfcQuantityVolume('NetVolume',$,$,9844311.91169991,$)
# #165075=IfcQuantityArea('NetSideArea',$,$,1968862.38233998,$)
# #165076=IfcQuantityArea('NetSideArea',$,$,1.96886238233998,$)
# #165077=IfcQuantityVolume('NetVolume',$,$,0.00984431191169988,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 0.554999999999995
# Property Facet call function triggered
# #165184=IfcQuantityLength('Height',$,$,565.000000000235,$)
# #165185=IfcQuantityLength('Length',$,$,7513.22389918773,$)
# #165186=IfcQuantityLength('Width',$,$,5.,$)
# #165187=IfcQuantityArea('GrossFootprintArea',$,$,0.0375661194959348,$)
# #165188=IfcQuantityVolume('NetVolume',$,$,21224857.5152142,$)
# #165189=IfcQuantityArea('NetSideArea',$,$,4244971.50304284,$)
# #165190=IfcQuantityArea('NetSideArea',$,$,4.24497150304281,$)
# #165191=IfcQuantityVolume('NetVolume',$,$,0.0212248575152141,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 0.565000000000235
# Property Facet call function triggered
# #165298=IfcQuantityLength('Height',$,$,565.000000000235,$)
# #165299=IfcQuantityLength('Length',$,$,7100.,$)
# #165300=IfcQuantityLength('Width',$,$,5.,$)
# #165301=IfcQuantityArea('GrossFootprintArea',$,$,0.0355000000000024,$)
# #165302=IfcQuantityVolume('NetVolume',$,$,20057500.0000084,$)
# #165303=IfcQuantityArea('NetSideArea',$,$,4011500.00000167,$)
# #165304=IfcQuantityArea('NetSideArea',$,$,4.01150000000164,$)
# #165305=IfcQuantityVolume('NetVolume',$,$,0.0200575000000073,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 0.565000000000235
# Property Facet call function triggered
# #165455=IfcQuantityLength('Height',$,$,1430.,$)
# #165456=IfcQuantityLength('Length',$,$,1830.,$)
# #165457=IfcQuantityLength('Width',$,$,300.,$)
# #165458=IfcQuantityArea('GrossFootprintArea',$,$,0.549,$)
# #165459=IfcQuantityVolume('NetVolume',$,$,785070000.000002,$)
# #165460=IfcQuantityArea('NetSideArea',$,$,2616900.00000001,$)
# #165461=IfcQuantityArea('NetSideArea',$,$,0.381602053949104,$)
# #165462=IfcQuantityVolume('NetVolume',$,$,0.114480616184731,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 1.43
# Property Facet call function triggered
# #166233=IfcQuantityLength('Height',$,$,2962.18399246247,$)
# #166234=IfcQuantityLength('Length',$,$,427.500217183621,$)
# #166235=IfcQuantityLength('Width',$,$,122.,$)
# #166236=IfcQuantityArea('GrossFootprintArea',$,$,0.0521550264964019,$)
# #166237=IfcQuantityVolume('NetVolume',$,$,154492784.614097,$)
# #166238=IfcQuantityArea('NetSideArea',$,$,1266334.30011555,$)
# #166239=IfcQuantityArea('NetSideArea',$,$,1.26633430011555,$)
# #166240=IfcQuantityVolume('NetVolume',$,$,0.154492784614097,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.96218399246247
# Property Facet call function triggered
# #166413=IfcQuantityLength('Height',$,$,3230.00000000015,$)
# #166414=IfcQuantityLength('Length',$,$,4170.04766580784,$)
# #166415=IfcQuantityLength('Width',$,$,200.,$)
# #166416=IfcQuantityArea('GrossFootprintArea',$,$,0.834009533161595,$)
# #166417=IfcQuantityVolume('NetVolume',$,$,2693850792.11199,$)
# #166418=IfcQuantityArea('NetSideArea',$,$,13469253.9605599,$)
# #166419=IfcQuantityArea('NetSideArea',$,$,13.4692539605599,$)
# #166420=IfcQuantityVolume('NetVolume',$,$,2.69385079211196,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.23000000000015
# whateverland?
# Property Facet call function triggered
# #166523=IfcQuantityLength('Height',$,$,2880.,$)
# #166524=IfcQuantityLength('Length',$,$,935.999999999994,$)
# #166525=IfcQuantityLength('Width',$,$,83.,$)
# #166526=IfcQuantityArea('GrossFootprintArea',$,$,0.0776879999999981,$)
# #166527=IfcQuantityVolume('NetVolume',$,$,223741439.999999,$)
# #166528=IfcQuantityArea('NetSideArea',$,$,2695679.99999999,$)
# #166529=IfcQuantityArea('NetSideArea',$,$,2.69567999999998,$)
# #166530=IfcQuantityVolume('NetVolume',$,$,0.223741439999994,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.88
# Property Facet call function triggered
# #172776=IfcQuantityLength('Height',$,$,3079.99999999999,$)
# #172777=IfcQuantityLength('Length',$,$,20268.3053850364,$)
# #172778=IfcQuantityLength('Width',$,$,250.,$)
# #172779=IfcQuantityArea('GrossFootprintArea',$,$,4.53488993167256,$)
# #172780=IfcQuantityVolume('NetVolume',$,$,15606595146.478,$)
# #172781=IfcQuantityArea('NetSideArea',$,$,62426380.585912,$)
# #172782=IfcQuantityArea('NetSideArea',$,$,49.8823805859121,$)
# #172783=IfcQuantityVolume('NetVolume',$,$,11.1608297383321,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.07999999999999
# whateverland?
# Property Facet call function triggered
# #172910=IfcQuantityLength('Height',$,$,2230.,$)
# #172911=IfcQuantityLength('Length',$,$,376.457404210984,$)
# #172912=IfcQuantityLength('Width',$,$,200.,$)
# #172913=IfcQuantityArea('GrossFootprintArea',$,$,0.0752914808421959,$)
# #172914=IfcQuantityVolume('NetVolume',$,$,167900002.278099,$)
# #172915=IfcQuantityArea('NetSideArea',$,$,839500.011390496,$)
# #172916=IfcQuantityArea('NetSideArea',$,$,0.839500011390496,$)
# #172917=IfcQuantityVolume('NetVolume',$,$,0.167900002278101,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.23
# Property Facet call function triggered
# #173022=IfcQuantityLength('Height',$,$,3009.99999999999,$)
# #173023=IfcQuantityLength('Length',$,$,4574.16285848192,$)
# #173024=IfcQuantityLength('Width',$,$,200.,$)
# #173025=IfcQuantityArea('GrossFootprintArea',$,$,0.914832571696381,$)
# #173026=IfcQuantityVolume('NetVolume',$,$,2753646040.80611,$)
# #173027=IfcQuantityArea('NetSideArea',$,$,13768230.2040305,$)
# #173028=IfcQuantityArea('NetSideArea',$,$,13.7682302040306,$)
# #173029=IfcQuantityVolume('NetVolume',$,$,2.7536460408061,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.00999999999999
# whateverland?
# Property Facet call function triggered
# #173517=IfcQuantityLength('Height',$,$,3110.00000000008,$)
# #173518=IfcQuantityLength('Length',$,$,20268.3053850364,$)
# #173519=IfcQuantityLength('Width',$,$,240.,$)
# #173520=IfcQuantityVolume('NetVolume',$,$,15128263139.3916,$)
# #173521=IfcQuantityArea('NetSideArea',$,$,63034429.7474649,$)
# #173522=IfcQuantityArea('NetSideArea',$,$,50.4904297474649,$)
# #173523=IfcQuantityVolume('NetVolume',$,$,11.9915942193591,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.1100000000000803
# whateverland?
# Property Facet call function triggered
# #173810=IfcQuantityLength('Height',$,$,3109.99999999999,$)
# #173811=IfcQuantityLength('Length',$,$,5457.70233581151,$)
# #173812=IfcQuantityLength('Width',$,$,270.,$)
# #173813=IfcQuantityArea('GrossFootprintArea',$,$,1.46734280075576,$)
# #173814=IfcQuantityVolume('NetVolume',$,$,4582832651.38092,$)
# #173815=IfcQuantityArea('NetSideArea',$,$,16973454.2643738,$)
# #173816=IfcQuantityArea('NetSideArea',$,$,10.8254542643737,$)
# #173817=IfcQuantityVolume('NetVolume',$,$,2.90347611035036,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.10999999999999
# whateverland?
# Property Facet call function triggered
# #176774=IfcQuantityLength('Height',$,$,3680.00000000015,$)
# #176775=IfcQuantityLength('Length',$,$,1469.9363177678,$)
# #176776=IfcQuantityLength('Width',$,$,200.,$)
# #176777=IfcQuantityArea('GrossFootprintArea',$,$,0.293987263553557,$)
# #176778=IfcQuantityVolume('NetVolume',$,$,1081873129.87714,$)
# #176779=IfcQuantityArea('NetSideArea',$,$,5409365.64938572,$)
# #176780=IfcQuantityArea('NetSideArea',$,$,5.40936564938572,$)
# #176781=IfcQuantityVolume('NetVolume',$,$,1.08187312987714,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.6800000000001503
# whateverland?
# Property Facet call function triggered
# #183925=IfcQuantityLength('Height',$,$,570.000000000035,$)
# #183926=IfcQuantityLength('Length',$,$,6651.15243360438,$)
# #183927=IfcQuantityLength('Width',$,$,150.,$)
# #183928=IfcQuantityArea('GrossFootprintArea',$,$,0.995392341723871,$)
# #183929=IfcQuantityVolume('NetVolume',$,$,568673533.07321,$)
# #183930=IfcQuantityArea('NetSideArea',$,$,3791156.88715473,$)
# #183931=IfcQuantityArea('NetSideArea',$,$,3.79115688715473,$)
# #183932=IfcQuantityVolume('NetVolume',$,$,0.567373634782642,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 0.570000000000035
# Property Facet call function triggered
# #185976=IfcQuantityLength('Height',$,$,3040.,$)
# #185977=IfcQuantityLength('Length',$,$,1338.84704282616,$)
# #185978=IfcQuantityLength('Width',$,$,250.,$)
# #185979=IfcQuantityArea('GrossFootprintArea',$,$,0.329364513504697,$)
# #185980=IfcQuantityVolume('NetVolume',$,$,1017523752.54788,$)
# #185981=IfcQuantityArea('NetSideArea',$,$,4070095.01019153,$)
# #185982=IfcQuantityArea('NetSideArea',$,$,4.07009501019153,$)
# #185983=IfcQuantityVolume('NetVolume',$,$,1.00126812105428,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.04
# whateverland?
# Property Facet call function triggered
# #186086=IfcQuantityLength('Height',$,$,3149.99999999999,$)
# #186087=IfcQuantityLength('Length',$,$,1215.49444631156,$)
# #186088=IfcQuantityLength('Width',$,$,250.,$)
# #186089=IfcQuantityArea('GrossFootprintArea',$,$,0.30387361157789,$)
# #186090=IfcQuantityVolume('NetVolume',$,$,957201876.470351,$)
# #186091=IfcQuantityArea('NetSideArea',$,$,3828807.5058814,$)
# #186092=IfcQuantityArea('NetSideArea',$,$,3.8288075058814,$)
# #186093=IfcQuantityVolume('NetVolume',$,$,0.957201876470348,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.14999999999999
# whateverland?
# Property Facet call function triggered
# #186196=IfcQuantityLength('Height',$,$,2290.00000000013,$)
# #186197=IfcQuantityLength('Length',$,$,1248.12499335808,$)
# #186198=IfcQuantityLength('Width',$,$,250.,$)
# #186199=IfcQuantityArea('GrossFootprintArea',$,$,0.31203124833952,$)
# #186200=IfcQuantityVolume('NetVolume',$,$,714551558.697543,$)
# #186201=IfcQuantityArea('NetSideArea',$,$,2858206.23479017,$)
# #186202=IfcQuantityArea('NetSideArea',$,$,2.85820623479017,$)
# #186203=IfcQuantityVolume('NetVolume',$,$,0.714551558697541,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 2.29000000000013
# Property Facet call function triggered
# #186307=IfcQuantityLength('Height',$,$,3110.00000000009,$)
# #186308=IfcQuantityLength('Length',$,$,531.418084727898,$)
# #186309=IfcQuantityLength('Width',$,$,205.,$)
# #186310=IfcQuantityArea('GrossFootprintArea',$,$,0.105345333197627,$)
# #186311=IfcQuantityVolume('NetVolume',$,$,338805599.918281,$)
# #186312=IfcQuantityArea('NetSideArea',$,$,1652710.24350381,$)
# #186313=IfcQuantityArea('NetSideArea',$,$,1.65271024350381,$)
# #186314=IfcQuantityVolume('NetVolume',$,$,0.327623986244632,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.11000000000009
# whateverland?
# Property Facet call function triggered
# #186467=IfcQuantityLength('Height',$,$,3079.99999999999,$)
# #186468=IfcQuantityLength('Length',$,$,645.058767743156,$)
# #186469=IfcQuantityLength('Width',$,$,205.,$)
# #186470=IfcQuantityArea('GrossFootprintArea',$,$,0.132237047387348,$)
# #186471=IfcQuantityVolume('NetVolume',$,$,407290105.953028,$)
# #186472=IfcQuantityArea('NetSideArea',$,$,1986781.00464892,$)
# #186473=IfcQuantityArea('NetSideArea',$,$,1.98678100464892,$)
# #186474=IfcQuantityVolume('NetVolume',$,$,0.40729010595303,$)
# True None
# True None
# True None
# {'maxInclusive': '3'}
# 3.07999999999999
# whateverland?
# Property Facet call function triggered
# #186663=IfcQuantityLength('Height',$,$,2540.00000000004,$)
# #186664=IfcQuantityLength('Length',$,$,3987.09882570856,$)
# #186665=IfcQuantityLength('Width',$,$,230.,$)
# #186666=IfcQuantityArea('GrossFootprintArea',$,$,0.917032729912968,$)
# #186667=IfcQuantityVolume('NetVolume',$,$,2329263133.97898,$)
# #186668=IfcQuantityArea('NetSideArea',$,$,10127231.0172999,$)
# #186669=IfcQuantityArea('NetSideArea',$,$,3.68396663438143,$)
# #186670=IfcQuantityVolume('NetVolume',$,$,0.847312325907727,$)
# True None
# True None
# True None
# ...
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1267603=IfcWall('2Gh3OAmL16TwdRJ3zxE49T',#42,'Basic Wall:242 - Eksisterende påforing langs fasade 140mm:13529711',$,'Basic Wall:242 - Eksisterende påforing langs fasade 140mm',#1267578,#1267599,'13529711',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1267713=IfcWall('2Gh3OAmL16TwdRJ3zxE46g',#42,'Basic Wall:242 - Eksisterende påforing langs fasade 140mm:13529722',$,'Basic Wall:242 - Eksisterende påforing langs fasade 140mm',#1267688,#1267709,'13529722',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1267823=IfcWall('2Gh3OAmL16TwdRJ3zxE46h',#42,'Basic Wall:242 - Eksisterende påforing langs fasade 140mm:13529723',$,'Basic Wall:242 - Eksisterende påforing langs fasade 140mm',#1267798,#1267819,'13529723',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1268009=IfcWall('2Gh3OAmL16TwdRJ3zxE40L',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13529742',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1267910,#1268005,'13529742',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1268248=IfcWall('2Gh3OAmL16TwdRJ3zxE40I',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13529743',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1268149,#1268244,'13529743',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1268360=IfcWall('2Gh3OAmL16TwdRJ3zxE40J',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13529744',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1268335,#1268356,'13529744',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1268538=IfcWall('2Gh3OAmL16TwdRJ3zxE4zO',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13529745',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1268445,#1268534,'13529745',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1268716=IfcWall('2Gh3OAmL16TwdRJ3zxE4zP',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13529746',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1268623,#1268712,'13529746',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1268828=IfcWall('2Gh3OAmL16TwdRJ3zxE4zM',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13529747',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1268803,#1268824,'13529747',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1269006=IfcWall('3lWvrYW_D8qevY3GvJLTI2',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13529775',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1268913,#1269002,'13529775',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1269184=IfcWall('3lWvrYW_D8qevY3GvJLTIT',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13529776',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1269091,#1269180,'13529776',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1269296=IfcWall('3lWvrYW_D8qevY3GvJLTIS',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13529777',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1269271,#1269292,'13529777',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1269472=IfcWall('3lWvrYW_D8qevY3GvJLTCZ',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13530382',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1269381,#1269468,'13530382',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1269654=IfcWall('3lWvrYW_D8qevY3GvJLTCY',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13530383',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1269557,#1269650,'13530383',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1269764=IfcWall('3lWvrYW_D8qevY3GvJLTCz',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13530384',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1269739,#1269760,'13530384',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1269952=IfcWall('3lWvrYW_D8qevY3GvJLT0R',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13530678',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1269851,#1269948,'13530678',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1270128=IfcWall('3lWvrYW_D8qevY3GvJLT0Q',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13530679',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1270037,#1270124,'13530679',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1270238=IfcWall('3lWvrYW_D8qevY3GvJLT0L',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13530680',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1270213,#1270234,'13530680',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1270426=IfcWall('3lWvrYW_D8qevY3GvJLT4P',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13530932',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1270325,#1270422,'13530932',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1270602=IfcWall('3lWvrYW_D8qevY3GvJLT4O',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13530933',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1270511,#1270598,'13530933',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1270715=IfcWall('3lWvrYW_D8qevY3GvJLT4R',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13530934',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1270687,#1270711,'13530934',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1270903=IfcWall('3mLjzpxjD5vfMl$UsTg$Dl',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532503',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1270802,#1270899,'13532503',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1271089=IfcWall('3mLjzpxjD5vfMl$UsTg$Dk',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532504',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1270990,#1271085,'13532504',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1271201=IfcWall('3mLjzpxjD5vfMl$UsTg$Dj',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532505',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1271176,#1271197,'13532505',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1271314=IfcWall('3mLjzpxjD5vfMl$UsTg$9X',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532507',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1271288,#1271310,'13532507',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1271465=IfcWall('3mLjzpxjD5vfMl$UsTg$9W',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532508',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1271440,#1271461,'13532508',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1271577=IfcWall('3mLjzpxjD5vfMl$UsTg$9d',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532509',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1271552,#1271573,'13532509',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1271765=IfcWall('3mLjzpxjD5vfMl$UsTg$4M',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532516',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1271664,#1271761,'13532516',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1271878=IfcWall('3mLjzpxjD5vfMl$UsTg$4L',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532517',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1271852,#1271874,'13532517',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1271990=IfcWall('3mLjzpxjD5vfMl$UsTg$4K',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532518',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1271965,#1271986,'13532518',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1272605=IfcWall('3mLjzpxjD5vfMl$UsTg$QD',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532630',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1272577,#1272601,'13532630',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1272717=IfcWall('3mLjzpxjD5vfMl$UsTg$QC',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532631',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1272692,#1272713,'13532631',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1272905=IfcWall('3mLjzpxjD5vfMl$UsTg$Kw',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532769',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1272804,#1272901,'13532769',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1273093=IfcWall('3mLjzpxjD5vfMl$UsTg$Kv',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532770',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1272992,#1273089,'13532770',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1273205=IfcWall('3mLjzpxjD5vfMl$UsTg$Ku',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13532771',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1273180,#1273201,'13532771',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1273393=IfcWall('2$4bg2z6r3AALv_j8CAZ77',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533066',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1273292,#1273389,'13533066',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1273581=IfcWall('2$4bg2z6r3AALv_j8CAZ76',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533067',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1273480,#1273577,'13533067',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1273693=IfcWall('2$4bg2z6r3AALv_j8CAZ71',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533068',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1273668,#1273689,'13533068',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1273881=IfcWall('2$4bg2z6r3AALv_j8CAizm',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533501',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1273780,#1273877,'13533501',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1274069=IfcWall('2$4bg2z6r3AALv_j8CAizp',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533502',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1273968,#1274065,'13533502',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1274181=IfcWall('2$4bg2z6r3AALv_j8CAizo',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533503',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1274156,#1274177,'13533503',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1274369=IfcWall('2$4bg2z6r3AALv_j8CAiyv',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533556',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1274268,#1274365,'13533556',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1274557=IfcWall('2$4bg2z6r3AALv_j8CAiyu',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533557',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1274456,#1274553,'13533557',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1274669=IfcWall('2$4bg2z6r3AALv_j8CAiyx',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533558',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1274644,#1274665,'13533558',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1274857=IfcWall('2$4bg2z6r3AALv_j8CAimt',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533818',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1274756,#1274853,'13533818',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1275045=IfcWall('2$4bg2z6r3AALv_j8CAims',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533819',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1274944,#1275041,'13533819',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1275157=IfcWall('2$4bg2z6r3AALv_j8CAimn',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13533820',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1275132,#1275153,'13533820',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1275345=IfcWall('2$4bg2z6r3AALv_j8CAit_',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13534131',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1275244,#1275341,'13534131',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1275533=IfcWall('2$4bg2z6r3AALv_j8CAitv',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13534132',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1275432,#1275529,'13534132',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1275645=IfcWall('2$4bg2z6r3AALv_j8CAitu',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13534133',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1275620,#1275641,'13534133',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1275833=IfcWall('3WY90UDCr7iOUEbYccqqW7',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13534428',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1275732,#1275829,'13534428',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1276021=IfcWall('3WY90UDCr7iOUEbYccqqW6',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13534429',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1275920,#1276017,'13534429',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1276133=IfcWall('3WY90UDCr7iOUEbYccqqW5',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13534430',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1276108,#1276129,'13534430',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1276507=IfcWall('3WY90UDCr7iOUEbYccqqay',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13534695',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1276407,#1276503,'13534695',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1276807=IfcWall('3WY90UDCr7iOUEbYccqqfz',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13534886',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1276706,#1276803,'13534886',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1276995=IfcWall('3WY90UDCr7iOUEbYccqqfy',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13534887',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1276894,#1276991,'13534887',.NOTDEFINED.)"},
#       {'reason': 'The attribute value "None" is empty',
#        'element': "#1277107=IfcWall('3WY90UDCr7iOUEbYccqqfp',#42,'Basic Wall:242 - Ny påforing langs fasade 140mm:13534888',$,'Basic Wall:242 - Ny påforing langs fasade 140mm',#1277082,#1277103,'13534888',.NOTDEFINED.)"},
#       ...]}]}]}

# %%
if not bool(0):
    print("yeo")
# Out:
# yeo
